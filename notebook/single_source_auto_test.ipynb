# %%
from uv_fit import *
best_auto_detect('../data/uv_test/11151_3c279_uvtable.fits')

# %%
from auto_detect_test import *

# %%
np.random.seed(42)  # for reproducibility

# %%
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p','p'], [0.03, 1], [(0, 0), (8, -10)], 0.0003)
sim_auto_detect(info, vis, n_sources=2, clean_output=True, corner_plot=True)

# %%
# Case: High SNR point source at field center
average_points('../data/uv_test/3c84.uvfits', ['p'], [1], [(0,0)], 0.0003)

# %%
# Case: Moderate SNR point source at field center
average_points('../data/uv_test/3c84.uvfits', ['p'], [0.002], [(0, 0)], 0.0003)

# %%
# Case: Low SNR point source at field center
average_points('../data/uv_test/3c84.uvfits', ['p'], [0.0012], [(0, 0)], 0.0003)

# %%
# Case: High SNR point source offset from field center
average_points('../data/uv_test/3c84.uvfits', ['p'], [1], [(10, -10)], 0.0003)

# %%
# Case: Moderate SNR point source offset from field center
average_points('../data/uv_test/3c84.uvfits', ['p'], [0.002], [(10, -10)], 0.0003)

# %%
# Case: Low SNR point source offset from field center
average_points('../data/uv_test/3c84.uvfits', ['p'], [0.0012], [(10, -10)], 0.0003)

# %%
# point source at field center with varying SNR
average_by_snr('../data/uv_test/3c84.uvfits', ['p'], [(0, 0)], 0.0003)

# %%
# point source offset from field center with varying SNR
average_by_snr('../data/uv_test/3c84.uvfits', ['p'], [(10, -10)], 0.0003)

# %%
from find_source import *
summary('../data/multi_track/3c279_11178.fits')
