# %%
from auto_detect_test import *

# %%
np.random.seed(42)  # for reproducibility

# %%
# 2 bright sources
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p','p'], [1, 1], [(0, 0), (10, -10)], 0.0003)
best_sim_auto_detect(info, vis, n_sources=None, clean_output=True, corner_plot=False)

# %%
# 1 bright, 1 moderate source
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p','p'], [1, 0.002], [(0, 0), (10, -10)], 0.0003)
best_sim_auto_detect(info, vis, n_sources=None, clean_output=True, corner_plot=False)

# %%
# 1 moderate, 1 bright source
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p','p'], [0.002, 1], [(0, 0), (10, -10)], 0.0003)
best_sim_auto_detect(info, vis, n_sources=None, clean_output=True, corner_plot=False)

# %%
# 1 bright, 1 dim source
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p','p'], [1, 0.0012], [(0, 0), (10, -10)], 0.0003)
best_sim_auto_detect(info, vis, n_sources=None, clean_output=True, corner_plot=False)

# %%
# 1 dim, 1 bright source
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p','p'], [0.0012, 1], [(0, 0), (10, -10)], 0.0003)
best_sim_auto_detect(info, vis, n_sources=None, clean_output=True, corner_plot=False)

# %%
# 3 bright sources
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p','p','p'], [1, 1, 1], [(0, 0), (10, -10), (-10, 10)], 0.0003)
best_sim_auto_detect(info, vis, n_sources=None, clean_output=True, corner_plot=False)

# %%
# 1 bright, 2 dim sources
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p','p','p'], [1, 0.0012, 0.0012], [(0, 0), (10, -10), (-10, 10)], 0.0003)
best_sim_auto_detect(info, vis, n_sources=None, clean_output=True, corner_plot=False)

# %%
# 1 bright, 2 moderate sources
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p','p','p'], [1, 0.002, 0.002], [(0, 0), (10, -10), (-10, 10)], 0.0003)
best_sim_auto_detect(info, vis, n_sources=None, clean_output=True, corner_plot=False)

# %%
# 1 bright, 2 fakes
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p'], [1], [(0, 0)], 0.0003)
info['ext_peak_val'] = [0.3, 0.3]
info['ext_peak_coord'] = [(10,-10), (-10,10)]
best_sim_auto_detect(info, vis, n_sources=None, clean_output=True, corner_plot=False)

# %%
# 1 bright, 1 fake
info, vis = generate_synthetic_info_vis('../data/uv_test/3c84.uvfits', ['p'], [1], [(0, 0)], 0.0003)
info['ext_peak_val'] = [0.3]
info['ext_peak_coord'] = [(10,-10)]
best_sim_auto_detect(info, vis, n_sources=None, clean_output=True, corner_plot=False)
